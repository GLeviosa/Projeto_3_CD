# %%
import pandas as pd

# %%
data1 = pd.read_csv('tmdb_5000_credits.csv')
data2 = pd.read_csv('tmdb_5000_movies.csv')

# %%
data_credits = data1.set_index('title')
data_movie = data2.set_index('title')

# %%
data_credits.head(3)
# Out:
#                                           movie_id  \
# title
# Avatar                                       19995
# Pirates of the Caribbean: At World's End       285
# Spectre                                     206647
#
#                                                                                        cast  \
# title
# Avatar                                    [{"cast_id": 242, "character": "Jake Sully", "...
# Pirates of the Caribbean: At World's End  [{"cast_id": 4, "character": "Captain Jack Spa...
# Spectre                                   [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                                                        crew
# title
# Avatar                                    [{"credit_id": "52fe48009251416c750aca23", "de...
# Pirates of the Caribbean: At World's End  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# Spectre                                   [{"credit_id": "54805967c3a36829b5002c41", "de...

# %%
data_movie.head(3)
# Out:
#                                              budget  \
# title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
#
#                                                                                      genres  \
# title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# Spectre                                   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                                               homepage  \
# title
# Avatar                                                     http://www.avatarmovie.com/
# Pirates of the Caribbean: At World's End  http://disney.go.com/disneypictures/pirates/
# Spectre                                    http://www.sonypictures.com/movies/spectre/
#
# ...

# %%
data = data_credits.join(data_movie, how="inner")

# %%
data.head(3)
# Out:
#                       movie_id  \
# title
# #Horror                 301325
# (500) Days of Summer     19913
# 10 Cloverfield Lane     333371
#
#                                                                    cast  \
# title
# #Horror               [{"cast_id": 0, "character": "Alex's 12-Step F...
# (500) Days of Summer  [{"cast_id": 4, "character": "Tom Hansen", "cr...
# 10 Cloverfield Lane   [{"cast_id": 2, "character": "Michelle", "cred...
#
#                                                                    crew  \
# title
# #Horror               [{"credit_id": "545bbac70e0a261fb6002329", "de...
# (500) Days of Summer  [{"credit_id": "52fe47f99251416c750abaa5", "de...
# 10 Cloverfield Lane   [{"credit_id": "57627624c3a3680682000872", "de...
#
#                         budget  \
# title
# #Horror                1500000
# (500) Days of Summer   7500000
# 10 Cloverfield Lane   15000000
#
#                                                                  genres  \
# title
# ...

# %%
df = data[['cast','crew', 'popularity', 'vote_average']]
df.sort_values(by="popularity", ascending=False)
# Out:
#                                                                                                  cast  \
# title
# Minions                                             [{"cast_id": 22, "character": "Scarlet Overkil...
# Interstellar                                        [{"cast_id": 9, "character": "Joseph Cooper", ...
# Deadpool                                            [{"cast_id": 99, "character": "Wade Wilson / D...
# Guardians of the Galaxy                             [{"cast_id": 1, "character": "Peter Quill / St...
# Mad Max: Fury Road                                  [{"cast_id": 2, "character": "Max Rockatansky"...
# Jurassic World                                      [{"cast_id": 10, "character": "Owen Grady", "c...
# Pirates of the Caribbean: The Curse of the Blac...  [{"cast_id": 12, "character": "Captain Jack Sp...
# Dawn of the Planet of the Apes                      [{"cast_id": 8, "character": "Caesar", "credit...
# ...

# %%
cast_total = []

for l in df.iterrows():
    lista_dic = eval(l[1]["cast"])
    for dic in lista_dic:
        dic["movie"] = l[0]
    cast_total.extend(lista_dic)

# %%
dados = pd.DataFrame.from_records(cast_total)

# %%
dados.head(6)
# Out:
#    cast_id              character                 credit_id  gender      id  \
# 0        0  Alex's 12-Step Friend  545bba84c3a3685358001b80       1     343
# 1        1              Sam's Mom  545bba8a0e0a261fad0023f6       1   10871
# 2        2               Alex Cox  545bba8fc3a36853500018a4       1    2838
# 3        3                Mr. Cox  545bba94c3a3685353001a56       2    9296
# 4        4              Dr. White  545bba990e0a261fb900220b       2   16327
# 5        5                   Lisa  545bba9ec3a368535d001e67       1  210573
#
#      movie             name  order
# 0  #Horror    Taryn Manning      1
# 1  #Horror   Natasha Lyonne      2
# 2  #Horror    Chloë Sevigny      3
# 3  #Horror  Balthazar Getty      4
# 4  #Horror   Timothy Hutton      5
# 5  #Horror     Lydia Hearst      6

# %%
atores = list(dados.name.value_counts().head(400).index)

# %%
#dados.to_excel("atuacoes.xlsx")
#dados.name.value_counts().to_excel("contagem.xlsx")
#df.to_excel('dataframe uhul.xlsx')

# %%
for i in atores:
    df[i] = 0
    
df
# Out:
# C:\Users\pvfon\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                                                         cast  \
# title
# #Horror                                    [{"cast_id": 0, "character": "Alex's 12-Step F...
# (500) Days of Summer                       [{"cast_id": 4, "character": "Tom Hansen", "cr...
# 10 Cloverfield Lane                        [{"cast_id": 2, "character": "Michelle", "cred...
# 10 Days in a Madhouse                      [{"cast_id": 2, "character": "Nellie Bly", "cr...
# 10 Things I Hate About You                 [{"cast_id": 2, "character": "Patrick Verona",...
# ...

# %%
for i in dados.itertuples():
    if i.name in df.columns:
        
        df.loc[i.movie, i.name] = 1

# %%
df
# Out:
#                                                                                         cast  \
# title
# #Horror                                    [{"cast_id": 0, "character": "Alex's 12-Step F...
# (500) Days of Summer                       [{"cast_id": 4, "character": "Tom Hansen", "cr...
# 10 Cloverfield Lane                        [{"cast_id": 2, "character": "Michelle", "cred...
# 10 Days in a Madhouse                      [{"cast_id": 2, "character": "Nellie Bly", "cr...
# 10 Things I Hate About You                 [{"cast_id": 2, "character": "Patrick Verona",...
# 102 Dalmatians                             [{"cast_id": 1, "character": "Cruella de Vil",...
# 10th & Wolf                                [{"cast_id": 1, "character": "Tommy", "credit_...
# 11:14                                      [{"cast_id": 10, "character": "Jack", "credit_...
# 12 Angry Men                               [{"cast_id": 29, "character": "Juror 8", "cred...
# ...
